# %%
import requests, json

apiKey = 'ac40e6c2cb345593ed1691e0a8b601bba398e42d85f81f893c5ab709cec63c6c'
searchUrl ='https://oc-index.library.ubc.ca/search?api_key='

with open('../request_objects/aggregate-creator.json') as json_data:
    queryObject = json.load(json_data)


print('QUERY OBJECT')
print(json.dumps(queryObject, indent=4))

search = requests.post(searchUrl + apiKey, json=queryObject)

#print('RESPONSE')
print(json.dumps(search.json(), indent=4))
# Out:
# QUERY OBJECT
# {
#     "size": 0,
#     "from": 0,
#     "search_type": "count",
#     "index": "macmillan",
#     "body": {
#         "aggregations": {
#             "creator": {
#                 "terms": {
#                     "size": 200,
#                     "field": "creator.raw"
#                 }
#             }
#         },
#         "query": {
#             "filtered": {
#                 "query": {
#                     "query_string": {
#                         "default_operator": "AND",
#                         "query": "*"
#                     }
#                 }
#             }
#         },
#         "_source": [
#             "creator",
#             "scholarlyLevel",
#             "ubc.date.sort",
#             "subject",
#             "title",
#             "type"
#         ]
#     }
# }
# {
#     "api_code": 3000,
#     "data": {
#         "data": {
#             "_shards": {
#                 "successful": 20,
#                 "total": 20,
#                 "failed": 0
#             },
#             "aggregations": {
#                 "creator": {
#                     "doc_count_error_upper_bound": 0,
#                     "buckets": [
#                         {
#                             "doc_count": 101,
#                             "key": "Frank, Leonard"
#                         },
#                         {
#                             "doc_count": 94,
#                             "key": "Cash, Jack"
#                         },
#                         {
#                             "doc_count": 85,
#                             "key": "Jack Cash Photographic Studios"
#                         },
#                         {
#                             "doc_count": 45,
#                             "key": "Lovick Studio"
#                         },
#                         {
#                             "doc_count": 29,
#                             "key": "Van Herd, Kevan"
#                         },
#                         {
#                             "doc_count": 26,
#                             "key": "Anton's Studios"
#                         },
#                         {
#                             "doc_count": 14,
#                             "key": "Powell River Studios"
#                         },
#                         {
#                             "doc_count": 13,
#                             "key": "Allan, George"
#                         },
#                         {
#                             "doc_count": 13,
#                             "key": "Grant, Harry"
#                         },
#                         {
#                             "doc_count": 13,
#                             "key": "Kemp, A.R."
#                         },
#                         {
#                             "doc_count": 10,
#                             "key": "Clegg, Joseph"
#                         },
#                         {
#                             "doc_count": 7,
#                             "key": "George Allen Aerial Photos Limited"
#                         },
#                         {
#                             "doc_count": 7,
#                             "key": "VanDusen, Whitford Julian, 1889-1978"
#                         },
#                         {
#                             "doc_count": 5,
#                             "key": "Anderson, K."
#                         },
#                         {
#                             "doc_count": 5,
#                             "key": "Clegg's Studio"
#                         },
#                         {
#                             "doc_count": 4,
#                             "key": "Harry Cantlon Photographers Limited"
#                         },
#                         {
#                             "doc_count": 4,
#                             "key": "Hermann, G.E."
#                         },
#                         {
#                             "doc_count": 4,
#                             "key": "Powell River Company Limited"
#                         },
#                         {
#                             "doc_count": 3,
#                             "key": "B.A. Photographers Limited"
#                         },
#                         {
#                             "doc_count": 3,
#                             "key": "British Columbia Government Travel Bureau"
#                         },
#                         {
#                             "doc_count": 3,
#                             "key": "Graphic Industries Limited"
#                         },
#                         {
#                             "doc_count": 3,
#                             "key": "National Film Board of Canada"
#                         },
#                         {
#                             "doc_count": 3,
#                             "key": "Wrathall, Jack"
#                         },
#                         {
#                             "doc_count": 2,
#                             "key": "Beattie Photographers"
#                         },
#                         {
#                             "doc_count": 2,
#                             "key": "Bridgman"
#                         },
#                         {
#                             "doc_count": 2,
#                             "key": "Johnston, Ray"
#                         },
#                         {
#                             "doc_count": 2,
#                             "key": "Selwyn Pullan Photography"
#                         },
#                         {
#                             "doc_count": 2,
#                             "key": "Williams Brothers Photographers Limited"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Blank and Stoller"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Cleveland-Kent"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Craftsman Photographers"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Davies, B."
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Davis, B"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Fraser, F.A."
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Jennings, B.C."
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "MacMillan, H.R. (Harvey Reginald), 1885-1976"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Olsen, O.H."
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Sparshatt & Barr"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Steffens-Colmer Studios Limited"
#                         },
#                         {
#                             "doc_count": 1,
#                             "key": "Svarre/Cantion Photographers Limited"
#                         }
#                     ],
#                     "sum_other_doc_count": 0
#                 }
#             },
#             "timed_out": false,
#             "took": 2,
#             "hits": {
#                 "hits": [],
#                 "total": 2730,
#                 "max_score": 0
#             }
#         }
#     },
#     "user_ip": "206.87.108.197",
#     "endpoint": "POST: /search",
#     "api_text": "Endpoint: /search | API Version: 1",
#     "http_code": 200
# }

# %%
import requests, json, matplotlib, numpy
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

apiKey = 'ac40e6c2cb345593ed1691e0a8b601bba398e42d85f81f893c5ab709cec63c6c'
searchUrl ='https://oc-index.library.ubc.ca/search?api_key='

with open('../request_objects/aggregate-date-subj-creator.json') as json_data:
    queryObject = json.load(json_data)


print('QUERY OBJECT')
print(json.dumps(queryObject, indent=4))

search = requests.post(searchUrl + apiKey, json=queryObject)

print('RESPONSE')
# print(json.dumps(search.json(), indent=4))

response = search.json()

date_hist = response['data']['data']['aggregations']['date_hist']['buckets']

print(json.dumps(date_hist, indent=4))

N = len(date_hist)

ind = numpy.arange(N)  # the x locations for the groups
width = 0.8       # the width of the bars

counts =  [ item['doc_count'] for item in date_hist ]
labels = [ item['key_as_string'] for item in date_hist ]


fig, ax = plt.subplots()
rects1 = ax.bar(ind, counts, width, color='r')


# add some text for labels, title and axes ticks
ax.set_ylabel('Count')
ax.set_title('Items by Date')
ax.set_xticks(ind + width)
ax.set_xticklabels(labels, fontsize=6)
fig.autofmt_xdate()

loc = plticker.MultipleLocator(base=3.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)


# ax.legend((rects1[0], rects2[0]), ('Men', 'Women'))

plt.show()
# Out:
# QUERY OBJECT
# {
#     "size": 0,
#     "from": 0,
#     "search_type": "count",
#     "index": "macmillan",
#     "body": {
#         "aggregations": {
#             "date_hist": {
#                 "aggregations": {
#                     "subject": {
#                         "terms": {
#                             "size": 60,
#                             "field": "subject.raw"
#                         }
#                     },
#                     "creator": {
#                         "terms": {
#                             "size": 60,
#                             "field": "creator.raw"
#                         }
#                     }
#                 },
#                 "date_histogram": {
#                     "field": "ubc.date.sort",
#                     "interval": "year",
#                     "format": "yyyy-MM-dd"
#                 }
#             }
#         },
#         "query": {
#             "filtered": {
#                 "filter": {
#                     "bool": {
#                         "must": []
#                     }
#                 },
#                 "query": {
#                     "query_string": {
#                         "default_operator": "AND",
#                         "query": "*"
#                     }
#                 }
#             }
#         },
#         "_source": [
#             "affiliation",
#             "campus",
#             "creator",
#             "dateAvailable",
#             "degree",
#             "description",
#             "genre",
#             "geographicLocation",
#             "program",
#             "scholarlyLevel",
#             "ubc.date.sort",
#             "subject",
#             "title",
#             "type",
#             "ubc.internal.handle",
#             "ubc.internal.provenance.nick",
#             "ubc.internal.repo"
#         ]
#     }
# }
# RESPONSE
# [
#     {
#         "doc_count": 2,
#         "key_as_string": "1854-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -3660595200000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 5,
#         "key_as_string": "1859-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -3502828800000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 4,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Commerce"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Eucalyptus trees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Machinery"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 2,
#         "key_as_string": "1863-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -3376598400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Commerce"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Ships"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Transportation"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 1,
#         "key_as_string": "1890-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -2524521600000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Ships"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 71,
#         "key_as_string": "1900-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 39,
#                     "key": "Frank, Leonard"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "National Film Board of Canada"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Wrathall, Jack"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Cash, Jack"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Davis, B"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -2208988800000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 47,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 20,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 14,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 9,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 8,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Paper industry"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Dams"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Employment"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Hydroelectric power"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Working life"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Activities"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Buildings"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Forest machinery"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Golfing"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Monuments & memorials"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Railroads"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Veterans"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "War"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "City & town life"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Dump trucks"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Paper processing"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Warehouses"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Beaches"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Cedar trees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Community centers"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lakes & ponds"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Libraries"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Railroad locomotives"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Railroad trains"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Steam donkeys"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Trees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Trucks"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 2,
#         "key_as_string": "1903-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -2114380800000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Donkey engines"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Employment"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 2,
#         "key_as_string": "1905-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -2051222400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Sawmills"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 1,
#         "key_as_string": "1906-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -2019686400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Donkey engines"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employment"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 14,
#         "key_as_string": "1907-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1988150400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 13,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 12,
#                     "key": "Camps"
#                 },
#                 {
#                     "doc_count": 12,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Lumber camps"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Bathtubs & showers"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Blacksmith shops"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Boats"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Cabins"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Dining rooms"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Kitchens"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Offices"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 5,
#         "key_as_string": "1909-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1924992000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 5,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Sawmills"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 14,
#         "key_as_string": "1910-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1893456000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 8,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Surveying"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Cedar trees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Boats"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Post offices"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 1,
#         "key_as_string": "1911-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1861920000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Forests and forestry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Management"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 3,
#         "key_as_string": "1912-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1830384000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 3,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Schools"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Ships"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 2,
#         "key_as_string": "1914-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1767225600000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Paper industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Sawmills"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 4,
#         "key_as_string": "1915-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1735689600000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 3,
#                     "key": "Piers & wharves"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 4,
#         "key_as_string": "1918-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1640995200000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Flagpoles"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Trees"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 8,
#         "key_as_string": "1920-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 3,
#                     "key": "Frank, Leonard"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Beattie Photographers"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Blank and Stoller"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1577923200000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 4,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Axes"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Offices"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Railroad locomotives"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Transportation"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 1,
#         "key_as_string": "1921-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1546300800000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 1,
#         "key_as_string": "1922-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Olsen, O.H."
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1514764800000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Railroads"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Transportation"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 3,
#         "key_as_string": "1925-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1420070400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 3,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Mills"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 33,
#         "key_as_string": "1926-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 33,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1388534400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 28,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 17,
#                     "key": "Sawmills"
#                 },
#                 {
#                     "doc_count": 13,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Camps"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Employment"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Buildings"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Hoisting machinery"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Tree stumps"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employee eating facilities"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Kitchens"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lakes & ponds"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumbering industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Railroads"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Saws"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Water supply"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Water tanks"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 2,
#         "key_as_string": "1927-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1356998400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Paper industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Safety"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Sawmills"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 2,
#         "key_as_string": "1928-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Bridgman"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1325462400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Basketball"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Employees"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 5,
#         "key_as_string": "1929-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 5,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1293840000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 3,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Aerial photographs"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 24,
#         "key_as_string": "1930-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 6,
#                     "key": "Clegg, Joseph"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Hermann, G.E."
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1262304000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 13,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 7,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Commerce"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Lakes & ponds"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Landscape photographs"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Piers & wharves"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Axes"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Camps"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Deer"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Firs"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Loading docks"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Trees"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 1,
#         "key_as_string": "1931-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1230768000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 5,
#         "key_as_string": "1933-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1167609600000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 4,
#                     "key": "Shipping"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 1,
#         "key_as_string": "1934-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1136073600000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Piers & wharves"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Waterfronts"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 23,
#         "key_as_string": "1936-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 7,
#                     "key": "VanDusen, Whitford Julian, 1889-1978"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "MacMillan, H.R. (Harvey Reginald), 1885-1976"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1073001600000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 15,
#                     "key": "Plywood"
#                 },
#                 {
#                     "doc_count": 8,
#                     "key": "Employees"
#                 },
#                 {
#                     "doc_count": 7,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 7,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Offices"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Building materials"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Exhibitions"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Clubs"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 6,
#         "key_as_string": "1937-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 1,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -1041379200000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 5,
#                     "key": "Plywood"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Automobiles"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Trailers"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Golf"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Offices"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 17,
#         "key_as_string": "1938-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -1009843200000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 14,
#                     "key": "Building materials"
#                 },
#                 {
#                     "doc_count": 14,
#                     "key": "Plywood"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Mills"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 12,
#         "key_as_string": "1939-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 6,
#                     "key": "Frank, Leonard"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Clegg, Joseph"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -978307200000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 7,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Dams"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Boats"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lakes & ponds"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Tugboats"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Office buildings"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Offices"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Paper industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Piers & wharves"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Safety"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Sawmills"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 8,
#         "key_as_string": "1940-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 7,
#                     "key": "Frank, Leonard"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -946771200000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 8,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Railroad locomotives"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Saws"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Ships"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 5,
#         "key_as_string": "1941-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -915148800000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Elms"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Bridges"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forestry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 69,
#         "key_as_string": "1942-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 5,
#                     "key": "Clegg's Studio"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Fraser, F.A."
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -883612800000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 58,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 24,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 13,
#                     "key": "Employment"
#                 },
#                 {
#                     "doc_count": 12,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 12,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 12,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Camps"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Railroads"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Trees"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Bridges"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Hoisting machinery"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Shovels"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Bulldozers"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Cedar trees"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Logging"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Cedar Trees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Donkey engines"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Fire prevention"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Firs"
#                 },
#                 {
# ...
#         "doc_count": 55,
#         "key_as_string": "1965-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 4,
#                     "key": "Anderson, K."
#                 }
#             ],
#             "sum_other_doc_count": 0
#         },
#         "key": -157766400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 44,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 20,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 20,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 16,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 15,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 13,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 13,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 10,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 9,
#                     "key": "Railroad trains"
#                 },
#                 {
#                     "doc_count": 9,
#                     "key": "Railroads"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Paper industry"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Boats"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Cities & towns"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Rites & ceremonies"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Locomotives"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Office buildings"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Railroad locomotives"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Town meetings"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Dikes"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employment"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Pollution"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Trucks"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 96,
#         "key_as_string": "1966-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -126230400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 96,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 87,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 87,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 87,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 19,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 8,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 8,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Buildings"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Piers & wharves"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Storage facilities"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Camps"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Cities & towns"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Hoisting machinery"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Railroads"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 309,
#         "key_as_string": "1967-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -94694400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 307,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 304,
#                     "key": "Mills"
#                 },
#                 {
#                     "doc_count": 303,
#                     "key": "Industrialization"
#                 },
#                 {
#                     "doc_count": 300,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 166,
#                     "key": "Machinery"
#                 },
#                 {
#                     "doc_count": 22,
#                     "key": "Buildings"
#                 },
#                 {
#                     "doc_count": 7,
#                     "key": "Loading docks"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Centennial celebrations"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Waterwheels"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Saws"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Hoisting machinery"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber inudstry"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Offices"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Air compressors"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Bark"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Control rooms"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Housing"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 22,
#         "key_as_string": "1968-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -63158400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 16,
#                     "key": "Office buildings"
#                 },
#                 {
#                     "doc_count": 7,
#                     "key": "Rites & ceremonies"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Cities & towns"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Villages"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Inaugurations"
#                 },
#                 {
#                     "doc_count": 4,
#                     "key": "Children"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 46,
#         "key_as_string": "1969-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": -31536000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 41,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 37,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 37,
#                     "key": "Logs"
#                 },
#                 {
#                     "doc_count": 33,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 25,
#                     "key": "Railroads"
#                 },
#                 {
#                     "doc_count": 13,
#                     "key": "Railroad trains"
#                 },
#                 {
#                     "doc_count": 7,
#                     "key": "Water"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Construction"
#                 },
#                 {
#                     "doc_count": 5,
#                     "key": "Office buildings"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Equipment"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Lumber"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Employees"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Employment"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Helicopters"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Snow removal"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Trucks"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 14,
#         "key_as_string": "1971-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": 31536000000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 8,
#                     "key": "Forestry"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 6,
#                     "key": "Rites & ceremonies"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 4,
#         "key_as_string": "1973-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": 94694400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 3,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Shipping"
#                 },
#                 {
#                     "doc_count": 3,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Paper industry"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 12,
#         "key_as_string": "1975-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": 157766400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Airplanes"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Conservation of natural resources"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Seaplanes"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Tugboats"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Electric lines"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Forests"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Knots & splices"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Plants"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Sawmills"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Saws"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Transportation"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Willows"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Wood"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Wood waste"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     },
#     {
#         "doc_count": 3,
#         "key_as_string": "1976-01-01",
#         "creator": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [],
#             "sum_other_doc_count": 0
#         },
#         "key": 189302400000,
#         "subject": {
#             "doc_count_error_upper_bound": 0,
#             "buckets": [
#                 {
#                     "doc_count": 2,
#                     "key": "Conservation of natural resources"
#                 },
#                 {
#                     "doc_count": 2,
#                     "key": "Lumber industry"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Contests"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Logrolling"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Sports"
#                 },
#                 {
#                     "doc_count": 1,
#                     "key": "Trees"
#                 }
#             ],
#             "sum_other_doc_count": 0
#         }
#     }
# ]

# %%
import json, re, string, nltk

with open('../metadata.json') as json_data:
    metadata = json.load(json_data)

print(json.dumps(metadata,indent=4))

fullTexts=[]
for i in metadata:
    fullTexts.append(i['FullText'][0]['value'])
    
print(len(''.join(fullTexts)))
